# %%
import numpy as np

# %%
from sklearn.preprocessing import  MinMaxScaler

# %%
data = np.random.randint(0,100,(10,2))

# %%
data
# Out:
# array([[10, 91],
#        [46, 53],
#        [43, 44],
#        [73, 79],
#        [28, 49],
#        [55, 57],
#        [91, 85],
#        [20, 84],
#        [44, 66],
#        [31, 56]])

# %%
scalerModel = MinMaxScaler()

# %%
type(scalerModel)
# Out:
# sklearn.preprocessing.data.MinMaxScaler

# %%
scalerModel.fit(data)
# Out:
# //anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
data
# Out:
#     f1  f2  f3  label
# 0   90  57   3     97
# 1   98   7  23     97
# 2   80  39  28     29
# 3   12  98  85     17
# 4    2  37  78     62
# 5   18  18  87     27
# 6   21  92  14      2
# 7   21  56  17     75
# 8   27   0  10     94
# 9   64  88   8     80
# 10  17  26  73     48
# 11  30  91  85     81
# 12  71  49  84     76
# 13  15  79  76     97
# 14  98  16  60     75
# 15  39  44  57     27
# 16  70  76  95     65
# 17  84  33  38     52
# 18  77  21  99     46
# 19  99  15  36     33
# 20  26  96  85     53
# 21  93  76  36     40
# 22  69  96  14     62
# 23  81  55   5     61
# 24  61  18  87     13
# 25  73  78  91     21
# 26  22  56  16     22
# 27  46  73  42     81
# 28  83  51   0     65
# 29  84  42  60     39
# 30  17  23  49     65
# 31  61  89  75      9
# 32  14  99  13     64
# 33  72  37  83     36
# 34  18  72  69     54
# 35  98  55  80     85
# 36  79  56  60     78
# 37  29  22   7     39
# 38  53  39  35     30
# 39  49  57  99     10
# 40  86  23   9     11
# 41  92  92  91     41
# 42  84   4  13     94
# 43  42  36  46     95
# 44   1  82  88     40
# 45  17  39  40     19
# 46  93   6  25     41
# 47  96  67  51     43
# 48  31  89  13     11
# 49  12  30  41     80

# %%
scalerModel.transform(data)
# Out:
# array([[0.        , 1.        ],
#        [0.44444444, 0.19148936],
#        [0.40740741, 0.        ],
#        [0.77777778, 0.74468085],
#        [0.22222222, 0.10638298],
#        [0.55555556, 0.27659574],
#        [1.        , 0.87234043],
#        [0.12345679, 0.85106383],
#        [0.41975309, 0.46808511],
#        [0.25925926, 0.25531915]])

# %%
# if u want to do. both of them together
scalerModel.fit_transform(data)
# Out:
# //anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[0.        , 1.        ],
#        [0.44444444, 0.19148936],
#        [0.40740741, 0.        ],
#        [0.77777778, 0.74468085],
#        [0.22222222, 0.10638298],
#        [0.55555556, 0.27659574],
#        [1.        , 0.87234043],
#        [0.12345679, 0.85106383],
#        [0.41975309, 0.46808511],
#        [0.25925926, 0.25531915]])

# %%
import pandas as pd

# %%
data = pd.DataFrame(data= np.random.randint(0,100,(50,4)), columns=['f1', 'f2', 'f3', 'label'])

# %%
data
# Out:
#     f1  f2  f3  label
# 0   90  57   3     97
# 1   98   7  23     97
# 2   80  39  28     29
# 3   12  98  85     17
# 4    2  37  78     62
# 5   18  18  87     27
# 6   21  92  14      2
# 7   21  56  17     75
# 8   27   0  10     94
# 9   64  88   8     80
# 10  17  26  73     48
# 11  30  91  85     81
# 12  71  49  84     76
# 13  15  79  76     97
# 14  98  16  60     75
# 15  39  44  57     27
# 16  70  76  95     65
# 17  84  33  38     52
# 18  77  21  99     46
# 19  99  15  36     33
# 20  26  96  85     53
# 21  93  76  36     40
# 22  69  96  14     62
# 23  81  55   5     61
# 24  61  18  87     13
# 25  73  78  91     21
# 26  22  56  16     22
# 27  46  73  42     81
# 28  83  51   0     65
# 29  84  42  60     39
# 30  17  23  49     65
# 31  61  89  75      9
# 32  14  99  13     64
# 33  72  37  83     36
# 34  18  72  69     54
# 35  98  55  80     85
# 36  79  56  60     78
# 37  29  22   7     39
# 38  53  39  35     30
# 39  49  57  99     10
# 40  86  23   9     11
# 41  92  92  91     41
# 42  84   4  13     94
# 43  42  36  46     95
# 44   1  82  88     40
# 45  17  39  40     19
# 46  93   6  25     41
# 47  96  67  51     43
# 48  31  89  13     11
# 49  12  30  41     80

# %%
X = data[['f1','f2','f3']]

# %%
X
# Out:
#     f1  f2  f3
# 0   90  57   3
# 1   98   7  23
# 2   80  39  28
# 3   12  98  85
# 4    2  37  78
# 5   18  18  87
# 6   21  92  14
# 7   21  56  17
# 8   27   0  10
# 9   64  88   8
# 10  17  26  73
# 11  30  91  85
# 12  71  49  84
# 13  15  79  76
# 14  98  16  60
# 15  39  44  57
# 16  70  76  95
# 17  84  33  38
# 18  77  21  99
# 19  99  15  36
# 20  26  96  85
# 21  93  76  36
# 22  69  96  14
# 23  81  55   5
# 24  61  18  87
# 25  73  78  91
# 26  22  56  16
# 27  46  73  42
# 28  83  51   0
# 29  84  42  60
# 30  17  23  49
# 31  61  89  75
# 32  14  99  13
# 33  72  37  83
# 34  18  72  69
# 35  98  55  80
# 36  79  56  60
# 37  29  22   7
# 38  53  39  35
# 39  49  57  99
# 40  86  23   9
# 41  92  92  91
# 42  84   4  13
# 43  42  36  46
# 44   1  82  88
# 45  17  39  40
# 46  93   6  25
# 47  96  67  51
# 48  31  89  13
# 49  12  30  41

# %% [raw]
# y = data['label']

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, **options)>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cb9e92cdfb83> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)
#
# NameError: name 'y' is not defined

# %%
X_train.shape

# %%
X_test.shape
