# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It is built on top of matplotlib and closely integrated with pandas data structures.
#
# Here is some of the functionality that seaborn offers:
#
# A dataset-oriented API for examining relationships between multiple variables
#
# Specialized support for using categorical variables to show observations or aggregate statistics
#
# Options for visualizing univariate or bivariate distributions and for comparing them between subsets of data
#
# Automatic estimation and plotting of linear regression models for different kinds dependent variables
#
# Convenient views onto the overall structure of complex datasets
#
# High-level abstractions for structuring multi-plot grids that let you easily build complex visualizations
#
# Concise control over matplotlib figure styling with several built-in themes
#
# Tools for choosing color palettes that faithfully reveal patterns in your data

# %% [markdown]
# ## RELATIONAL PLOTS relplot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
#sns.set_style("ticks")
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip",hue="smoker",col="time",size="day",
            style="size",data=tips);
#print(plt.style.available)
#hue color style pattern size variation col no. of graphs

# %% [markdown]
# !pip install --upgrade seaborn

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", col="region", kind="line",
            hue="event", style="event", data=fmri);

# %% [markdown]
# ## CATEGORICAL PLOT catplot()

# %%
import seaborn as sns 
tips = sns.load_dataset("tips")
sns.catplot(x="smoker", y="tip",hue="day",kind="swarm",data=tips)

# %% [markdown]
# *## COLOR PALLETE

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.hls_palette(8, l=0.5, s=.7))

# %%
import seaborn as sns 
sns.set_style("dark") 
#sns.set_palette(sns.husl_palette(l=.8, s=.2))  #setting color pallete

#sns.set_palette(sns.color_palette("Blues", 2))
sns.set_palette("BrBG")
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="swarm",  data=tips)

#strip(Default),swarm,violin,box,boxen

# %% [markdown]
# ## FACET GRID

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
tips=sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.scatter, "total_bill","tip")

# %%
import matplotlib.pyplot as plt
import numpy as np
bins = np.arange(0, 25, 5)
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill",bins=bins, color="r")

# %% [markdown]
# ## PAIR GRID

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
g = sns.PairGrid(tips)
g = g.map(plt.scatter)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
flight = sns.load_dataset("flights")
g = sns.PairGrid(flight,hue="month")
g = g.map(plt.scatter)
g=g.add_legend()

# %%
tips = sns.load_dataset("tips")
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
#g = g.add_legend()

# %% [markdown]
# ## DISTRIBUTION PLOT
# KDE can be a useful tool for plotting the shape of a distribution. Like the histogram, the KDE plots encode the density of observations on one axis with height along the other axis

# %%
import numpy as np
m=np.random.rand(100)
#print(m)
sns.distplot(m,kde=False,rug=True,bins=[0.0,0.3,0.6,1.0])

# %%
sns.distplot(m, kde=False)

# %%
sns.distplot(m, kde=False, rug=True)

# %%
sns.distplot(m, hist=False, rug=True);

# %%
# !pip install --upgrade seaborn

# %%
print(sns.style.available())

# %%
import seaborn as sns
import pandas as pd
#sns.set_style("whitegrid")
tips = pd.read_csv("temp.csv")
sns.relplot(x="name", y="age",kind="line",data=tips);

# %%
print(sns.)
